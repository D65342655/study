# %% [markdown]
# <a href="https://colab.research.google.com/github/D65342655/study/blob/main/pinterest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+2=
# Out:
# 3

# %%
a=2
b=3
data_add = a+b
print(data_add)
# Out:
# 5

# %%
data_sub = a-b
print(data_sub)
# Out:
# -1

# %%
data_mul = a*b
print(data_mul)
# Out:
# 6

# %%
data_div = a/b
print(data_div)
# Out:
# 0.6666666666666666

# %% [markdown]
# # หารมีเศษ

# %%
data=a//b# หารไม่มีเศษ
print(data)
# Out:
# 0

# %%
data = a%b # หารไม่มีเศษ
print(data)
# Out:
# 2

# %%
data=a**b
print(data)
# Out:
# 8

# %%
import pandas as pd #อ่านตารางพวกcategorical

# %%
data=pd.read_csv("PINS.csv") #กดรูปโฟลเดอ--->ดึงไฟล์มาไว้ในopen notebook--->ใช้คำสั่งแพนดาสดึงไฟล์มา

# %%
data.head(20)#head()เฉยๆคือการเรียกดูข้อมูล5ตัวแรก แต่ถ้าเป็นdata.head(x)จะเป็นการดึงข้อมูลxแรกมาอ่าน
# Out:
#           Date  Price   Open   High    Low    Vol. Change %
# 0   06/24/2025  35.74  34.45  35.78  34.06   9.27M    5.12%
# 1   06/23/2025  34.00  34.02  34.33  33.35   7.19M   -0.64%
# 2   06/20/2025  34.22  34.96  35.01  33.99  10.86M   -1.61%
# 3   06/18/2025  34.78  34.57  35.06  34.50   7.31M    0.69%
# 4   06/17/2025  34.54  35.02  35.25  34.45   7.67M   -1.93%
# 5   06/16/2025  35.22  34.22  35.29  34.21   8.29M    4.08%
# 6   06/13/2025  33.84  33.52  34.13  33.26   6.87M   -0.53%
# 7   06/12/2025  34.02  34.38  34.55  33.94   6.30M   -2.10%
# 8   06/11/2025  34.75  34.99  35.40  34.55   9.20M   -1.03%
# 9   06/10/2025  35.11  34.95  35.20  34.53  10.77M    2.84%
# 10  06/09/2025  34.14  34.54  34.98  34.12   9.88M   -0.18%
# 11  06/06/2025  34.20  34.47  34.50  33.74   8.11M    1.30%
# 12  06/05/2025  33.76  33.97  34.15  33.44  12.57M   -0.15%
# 13  06/04/2025  33.81  33.02  33.96  33.02  10.00M    2.05%
# 14  06/03/2025  33.13  33.05  33.53  32.31  14.49M    3.82%
# ...

# %%
data.tail(10)#tail()เฉยๆคือการเรียกดูข้อมูล5ตัวสุดท้ายย
# Out:
#           Date  Price   Open   High    Low    Vol. Change %
# 10  06/09/2025  34.14  34.54  34.98  34.12   9.88M   -0.18%
# 11  06/06/2025  34.20  34.47  34.50  33.74   8.11M    1.30%
# 12  06/05/2025  33.76  33.97  34.15  33.44  12.57M   -0.15%
# 13  06/04/2025  33.81  33.02  33.96  33.02  10.00M    2.05%
# 14  06/03/2025  33.13  33.05  33.53  32.31  14.49M    3.82%
# 15  06/02/2025  31.91  31.04  31.97  31.02   7.43M    2.57%
# 16  05/30/2025  31.11  30.96  31.19  30.45   8.75M    0.16%
# 17  05/29/2025  31.06  31.90  32.00  30.92   6.71M   -1.18%
# 18  05/28/2025  31.43  31.55  31.75  31.26   8.41M   -0.19%
# 19  05/27/2025  31.49  31.38  31.75  31.17  10.22M    1.91%

# %%
data.shape
# Out:
# (20, 7)

# %% [markdown]
# (แถว,คอลัม)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
x = data["High"]#การเก็บตัวแปรในอีกตัวแปร แต่ยังไม่ประกาศ

# %%
x#ประกาศละ
# Out:
# 0     35.78
# 1     34.33
# 2     35.01
# 3     35.06
# 4     35.25
# 5     35.29
# 6     34.13
# 7     34.55
# 8     35.40
# 9     35.20
# 10    34.98
# 11    34.50
# 12    34.15
# 13    33.96
# 14    33.53
# 15    31.97
# 16    31.19
# 17    32.00
# 18    31.75
# 19    31.75
# Name: High, dtype: float64

# %%
x.head(10)
# Out:
# 0    35.78
# 1    34.33
# 2    35.01
# 3    35.06
# 4    35.25
# 5    35.29
# 6    34.13
# 7    34.55
# 8    35.40
# 9    35.20
# Name: High, dtype: float64

# %%
y = data[["High","Low"]]

# %%
y
# Out:
# [['High', 'Low']]

# %%
y.tail(10)
# Out:
#      High    Low
# 10  34.98  34.12
# 11  34.50  33.74
# 12  34.15  33.44
# 13  33.96  33.02
# 14  33.53  32.31
# 15  31.97  31.02
# 16  31.19  30.45
# 17  32.00  30.92
# 18  31.75  31.26
# 19  31.75  31.17

# %%
y.value_counts()#นับจำนวนค่าที่ซ้ำกันในคอลัมน์
# Out:
# High   Low
# 31.19  30.45    1
# 31.75  31.17    1
#        31.26    1
# 31.97  31.02    1
# 32.00  30.92    1
# 33.53  32.31    1
# 33.96  33.02    1
# 34.13  33.26    1
# 34.15  33.44    1
# 34.33  33.35    1
# 34.50  33.74    1
# 34.55  33.94    1
# 34.98  34.12    1
# 35.01  33.99    1
# 35.06  34.50    1
# 35.20  34.53    1
# 35.25  34.45    1
# 35.29  34.21    1
# 35.40  34.55    1
# 35.78  34.06    1
# Name: count, dtype: int64

# %%
y.min()
# Out:
# High    31.19
# Low     30.45
# dtype: float64

# %%
x.max()
# Out:
# 35.78

# %%
y.describe()#ใช้สรุปข้อมูลสถิติทุกตัว
# Out:
#             High        Low
# count  20.000000  20.000000
# mean   33.989000  33.114500
# std     1.450263   1.396859
# min    31.190000  30.450000
# 25%    33.147500  32.047500
# 50%    34.415000  33.590000
# 75%    35.095000  34.142500
# max    35.780000  34.550000

# %%
y.isna()#หาตัวที่ไม่มีข้อมูล เพื่อclean
# Out:
#      High    Low
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False

# %%
list = [False,	False, False,	False,False,False,]
sum(list)#เอาข้อมูลจากisnaที่ถ้าTrue=ไม่มีข้อมูล False=มีข้อมูล มาบวกลบกันได้เพื่อดูว่าข้อมูลหายไปมากน้อยแค่ใหน
# Out:
# 0

# %%
y.isna().sum()#เหมือนอันข้างบน นับจำนวนค่าที่เป็น NaN (missing values หรือค่าที่หายไป) ในตัวแปร
# Out:
# High    0
# Low     0
# dtype: int64

# %%
x.isna().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#           Date  Price   Open   High    Low    Vol. Change %
# 0   06/24/2025  35.74  34.45  35.78  34.06   9.27M    5.12%
# 1   06/23/2025  34.00  34.02  34.33  33.35   7.19M   -0.64%
# 2   06/20/2025  34.22  34.96  35.01  33.99  10.86M   -1.61%
# 3   06/18/2025  34.78  34.57  35.06  34.50   7.31M    0.69%
# 4   06/17/2025  34.54  35.02  35.25  34.45   7.67M   -1.93%
# 5   06/16/2025  35.22  34.22  35.29  34.21   8.29M    4.08%
# 6   06/13/2025  33.84  33.52  34.13  33.26   6.87M   -0.53%
# 7   06/12/2025  34.02  34.38  34.55  33.94   6.30M   -2.10%
# 8   06/11/2025  34.75  34.99  35.40  34.55   9.20M   -1.03%
# 9   06/10/2025  35.11  34.95  35.20  34.53  10.77M    2.84%
# 10  06/09/2025  34.14  34.54  34.98  34.12   9.88M   -0.18%
# 11  06/06/2025  34.20  34.47  34.50  33.74   8.11M    1.30%
# 12  06/05/2025  33.76  33.97  34.15  33.44  12.57M   -0.15%
# 13  06/04/2025  33.81  33.02  33.96  33.02  10.00M    2.05%
# 14  06/03/2025  33.13  33.05  33.53  32.31  14.49M    3.82%
# ...

# %%
data.dropna()#เอาข้อมูลที่หายไปออก
# Out:
#           Date  Price   Open   High    Low    Vol. Change %
# 0   06/24/2025  35.74  34.45  35.78  34.06   9.27M    5.12%
# 1   06/23/2025  34.00  34.02  34.33  33.35   7.19M   -0.64%
# 2   06/20/2025  34.22  34.96  35.01  33.99  10.86M   -1.61%
# 3   06/18/2025  34.78  34.57  35.06  34.50   7.31M    0.69%
# 4   06/17/2025  34.54  35.02  35.25  34.45   7.67M   -1.93%
# 5   06/16/2025  35.22  34.22  35.29  34.21   8.29M    4.08%
# 6   06/13/2025  33.84  33.52  34.13  33.26   6.87M   -0.53%
# 7   06/12/2025  34.02  34.38  34.55  33.94   6.30M   -2.10%
# 8   06/11/2025  34.75  34.99  35.40  34.55   9.20M   -1.03%
# 9   06/10/2025  35.11  34.95  35.20  34.53  10.77M    2.84%
# 10  06/09/2025  34.14  34.54  34.98  34.12   9.88M   -0.18%
# 11  06/06/2025  34.20  34.47  34.50  33.74   8.11M    1.30%
# 12  06/05/2025  33.76  33.97  34.15  33.44  12.57M   -0.15%
# 13  06/04/2025  33.81  33.02  33.96  33.02  10.00M    2.05%
# 14  06/03/2025  33.13  33.05  33.53  32.31  14.49M    3.82%
# ...

# %%
data.dropna(axis=0)#เอาข้อมูลที่หายไปออก axis=0 → ลบ แถว ที่มี NaN axis=1 → ลบ คอลัมน์ ที่มี NaN
# Out:
#           Date  Price   Open   High    Low    Vol. Change %
# 0   06/24/2025  35.74  34.45  35.78  34.06   9.27M    5.12%
# 1   06/23/2025  34.00  34.02  34.33  33.35   7.19M   -0.64%
# 2   06/20/2025  34.22  34.96  35.01  33.99  10.86M   -1.61%
# 3   06/18/2025  34.78  34.57  35.06  34.50   7.31M    0.69%
# 4   06/17/2025  34.54  35.02  35.25  34.45   7.67M   -1.93%
# 5   06/16/2025  35.22  34.22  35.29  34.21   8.29M    4.08%
# 6   06/13/2025  33.84  33.52  34.13  33.26   6.87M   -0.53%
# 7   06/12/2025  34.02  34.38  34.55  33.94   6.30M   -2.10%
# 8   06/11/2025  34.75  34.99  35.40  34.55   9.20M   -1.03%
# 9   06/10/2025  35.11  34.95  35.20  34.53  10.77M    2.84%
# 10  06/09/2025  34.14  34.54  34.98  34.12   9.88M   -0.18%
# 11  06/06/2025  34.20  34.47  34.50  33.74   8.11M    1.30%
# 12  06/05/2025  33.76  33.97  34.15  33.44  12.57M   -0.15%
# 13  06/04/2025  33.81  33.02  33.96  33.02  10.00M    2.05%
# 14  06/03/2025  33.13  33.05  33.53  32.31  14.49M    3.82%
# ...

# %%
data.dropna(axis=1)#เอาข้อมูลที่หายไปออก axis=0 → ลบ แถว ที่มี NaN axis=1 → ลบ คอลัมน์ ที่มี NaN
# Out:
#           Date  Price   Open   High    Low    Vol. Change %
# 0   06/24/2025  35.74  34.45  35.78  34.06   9.27M    5.12%
# 1   06/23/2025  34.00  34.02  34.33  33.35   7.19M   -0.64%
# 2   06/20/2025  34.22  34.96  35.01  33.99  10.86M   -1.61%
# 3   06/18/2025  34.78  34.57  35.06  34.50   7.31M    0.69%
# 4   06/17/2025  34.54  35.02  35.25  34.45   7.67M   -1.93%
# 5   06/16/2025  35.22  34.22  35.29  34.21   8.29M    4.08%
# 6   06/13/2025  33.84  33.52  34.13  33.26   6.87M   -0.53%
# 7   06/12/2025  34.02  34.38  34.55  33.94   6.30M   -2.10%
# 8   06/11/2025  34.75  34.99  35.40  34.55   9.20M   -1.03%
# 9   06/10/2025  35.11  34.95  35.20  34.53  10.77M    2.84%
# 10  06/09/2025  34.14  34.54  34.98  34.12   9.88M   -0.18%
# 11  06/06/2025  34.20  34.47  34.50  33.74   8.11M    1.30%
# 12  06/05/2025  33.76  33.97  34.15  33.44  12.57M   -0.15%
# 13  06/04/2025  33.81  33.02  33.96  33.02  10.00M    2.05%
# 14  06/03/2025  33.13  33.05  33.53  32.31  14.49M    3.82%
# ...

# %%
data["Low"].plot(kind="bar")#ทำdistribution
# Out:
# <Axes: >

# %%
data.plot(kind="scatter",x="High", y="Low")#ทำdistribution  แต่scatterต้องระบุแกนx, yด้วย
# Out:
# <Axes: xlabel='High', ylabel='Low'>
